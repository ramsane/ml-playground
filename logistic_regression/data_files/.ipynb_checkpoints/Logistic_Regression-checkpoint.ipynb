# %%
import numpy as np

import matplotlib  
matplotlib.use('nbagg')
import matplotlib.pyplot as plt


import sklearn

# %%
def plot_data(X, y):
    plt.scatter(X[:,0], X[:,1], c=y1, cmap='bwr')
    plt.show()

# %%
from sklearn.datasets import make_classification
from sklearn.datasets.samples_generator import make_blobs

# %% [markdown]
# # Make Blobs

# %%
X1, y1 = make_blobs(n_samples=300, n_features=2, centers=2,cluster_std=1.0,
                    center_box=(-5, 5), shuffle=True, random_state = 15)

plot_data(X1, y1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Min max scalar for rescaling the data..

# %%
scaler =  MinMaxScaler(feature_range=(-5, 5), copy=True);
X1_new = scaler.fit_transform(X1)

plot_data(X1_new, y1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
scaler =  MinMaxScaler(feature_range=(-5, 5), copy=True);
X1_new = scaler.fit_transform(X1)

plot_data(X1_new, y1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Scaling the data between -5 to 5.

# plt.scatter(X1[:,0], X1[:,1], c=y1, cmap='bwr')
# plt.show()

# %%
X1, y1 = make_classification(n_samples=300, n_features=2, n_redundant=0,
                           n_informative=1,n_clusters_per_class=1)


plt.scatter(X1[:,0], X1[:,1], c=y1, cmap='bwr')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
X2, y2 = make_classification(n_samples=150, n_features=2, n_redundant=0,
                           n_informative=2, random_state = 101)


plt.scatter(X2[:,0], X2[:,1], c=y2, cmap='bwr')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
X3, y3 = make_classification(n_samples=200, n_features=2, n_redundant=0,
                           n_informative=2, random_state = 20)


plt.scatter(X3[:,0], X3[:,1], c=y3, cmap='bwr')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import seaborn as sns
sns.set(style="white")

# %%
from sklearn.linear_model import LogisticRegression

# %%
X[100:,0].shape
# Out:
# (50,)

# %%
X, y = X2, y2

clf = LogisticRegression().fit(X, y)

xx, yy = np.mgrid[-5:5:.01, -5:5:.01]
grid = np.c_[xx.ravel(), yy.ravel()]
probs = clf.predict_proba(grid)[:, 1].reshape(xx.shape)

f, ax = plt.subplots(figsize=(8, 6))
contour = ax.contourf(xx, yy, probs, 25, cmap="RdBu",
                      vmin=0, vmax=1)
ax_c = f.colorbar(contour)
ax_c.set_label("$P(y = 1)$")
ax_c.set_ticks([0, .25, .5, .75, 1])

ax.scatter(X[:,0], X[:, 1], c=y[:], s=50,
           cmap="RdBu", vmin=-.2, vmax=1.2,
           edgecolor="white", linewidth=1)

ax.set(aspect="equal",
       xlim=(-5, 5), ylim=(-5, 5),
       xlabel="$X_1$", ylabel="$X_2$")

plt.show()

# %%
from sklearn.metrics import log_loss

# %%
y_pred = clf.predict_proba(X)

# %%
y_pred = y_pred[:,1]

# %%
log_loss(y, y_pred)

# %%
cls_data1 = np.column_stack((X1, y1))
cls_data2 = np.column_stack((X2, y2))
cls_data3 = np.column_stack((X3, y3))

# %% [markdown]
# =================================================================

# %% [markdown]
# ## Export this data into external csv file..

# %%
np.savetxt("lr_data1.csv", cls_data1, delimiter=',');
np.savetxt("lr_data2.csv", cls_data2, delimiter=',');
np.savetxt("lr_data3.csv", cls_data3, delimiter=',');

# %% [markdown]
# =================================================================
